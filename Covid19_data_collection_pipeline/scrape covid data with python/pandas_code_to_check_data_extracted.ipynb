# %%
import pandas as pd

# %%
df=pd.read_csv('covid19.csv')
df2 = pd.read_csv('covid19_v2.csv')
df3=pd.read_csv("covid19_v3.csv")

# %%
df2=df2.drop("#", axis=1)
df=df.drop("#", axis=1)
df3 = df3.drop("#", axis=1)

# %%
df2.columns
# Out:
# Index(['Country,Other', 'TotalCases', 'NewCases', 'TotalDeaths', 'NewDeaths',
#        'TotalRecovered', 'NewRecovered', 'ActiveCases', 'Serious,Critical',
#        'Tot Cases/1M pop', 'Deaths/1M pop', 'TotalTests', 'Tests/\n1M pop',
#        'Population', 'Continent', '1 Caseevery X ppl', '1 Deathevery X ppl',
#        '1 Testevery X ppl', 'New Cases/1M pop', 'New Deaths/1M pop',
#        'Active Cases/1M pop'],
#       dtype='object')

# %% [markdown]
# #### Columns those I will use : 'Country,Other', 'TotalCases', 'NewCases', 'TotalDeaths',
# #### 'NewDeaths', 'TotalRecovered', 'NewRecovered', 'ActiveCases', 'Serious,Critical', 'Population', 'Continent',

# %%
df2_selected = df2[['Country,Other', 'TotalCases', 'NewCases', 'TotalDeaths','NewDeaths', 'TotalRecovered', 'NewRecovered', 'ActiveCases', 'Serious,Critical', 'Population', 'Continent']]
df_selected = df[['Country,Other', 'TotalCases', 'NewCases', 'TotalDeaths','NewDeaths', 'TotalRecovered', 'NewRecovered', 'ActiveCases', 'Serious,Critical', 'Population', 'Continent']]
df3_selected = df3[['Country,Other', 'TotalCases', 'NewCases', 'TotalDeaths','NewDeaths', 'TotalRecovered', 'NewRecovered', 'ActiveCases', 'Serious,Critical', 'Population', 'Continent']]

# %%
df2_selected
# Out:
#       Country,Other   TotalCases NewCases TotalDeaths  NewDeaths  \
# 0     North America  131,614,510   +1,673   1,692,258        8.0
# 1              Asia  221,467,169     +120   1,553,255        1.0
# 2            Europe  253,232,601      +26   2,100,643        NaN
# 3     South America   69,859,756      NaN   1,365,807        NaN
# 4           Oceania   14,844,285     +441      32,767        NaN
# ..              ...          ...      ...         ...        ...
# 234         Tokelau           80      NaN         NaN        NaN
# 235    Vatican City           29      NaN         NaN        NaN
# 236  Western Sahara           10      NaN           1        NaN
# 237      MS Zaandam            9      NaN           2        NaN
# 238           China      503,302      NaN       5,272        NaN
#
#     TotalRecovered NewRecovered ActiveCases Serious,Critical     Population  \
# 0      127,145,461      +10,829   2,776,791            6,699            NaN
# ...

# %%
df_selected
# Out:
#       Country,Other   TotalCases  NewCases TotalDeaths  NewDeaths  \
# 0     North America  127,806,060       NaN   1,643,501        NaN
# 1              Asia  220,571,348       2.0   1,549,069        NaN
# 2            Europe  249,836,010       NaN   2,069,856        NaN
# 3     South America   68,958,962       NaN   1,360,127        NaN
# 4           Oceania   14,620,573       NaN      30,157        NaN
# ..              ...          ...       ...         ...        ...
# 234         Tokelau           80       NaN         NaN        NaN
# 235    Vatican City           29       NaN         NaN        NaN
# 236  Western Sahara           10       NaN           1        NaN
# 237      MS Zaandam            9       NaN           2        NaN
# 238           China      503,302       NaN       5,272        NaN
#
#     TotalRecovered NewRecovered ActiveCases Serious,Critical     Population  \
# 0      123,504,730         +291   2,657,829            6,319            NaN
# ...

# %%
df3_selected
# Out:
#       Country,Other   TotalCases  NewCases TotalDeaths  NewDeaths  \
# 0     North America  131,685,575       NaN   1,693,051        NaN
# 1              Asia  221,470,247       NaN   1,553,301        NaN
# 2            Europe  253,261,188       NaN   2,100,788        NaN
# 3     South America   69,859,756       NaN   1,365,807        NaN
# 4           Oceania   14,855,028     863.0      32,790        3.0
# ..              ...          ...       ...         ...        ...
# 234         Tokelau           80       NaN         NaN        NaN
# 235    Vatican City           29       NaN         NaN        NaN
# 236  Western Sahara           10       NaN           1        NaN
# 237      MS Zaandam            9       NaN           2        NaN
# 238           China      503,302       NaN       5,272        NaN
#
#     TotalRecovered NewRecovered ActiveCases Serious,Critical     Population  \
# 0      127,241,880         +651   2,750,644            6,580            NaN
# ...

# %%
df2 = df2_selected
df = df_selected
df3 = df3_selected

# %%
len(df2.columns)
# Out:
# 11

# %%
df.head()
# Out:
#    Country,Other   TotalCases  NewCases TotalDeaths  NewDeaths TotalRecovered  \
# 0  North America  127,806,060       NaN   1,643,501        NaN    123,504,730
# 1           Asia  220,571,348       2.0   1,549,069        NaN    203,882,636
# 2         Europe  249,836,010       NaN   2,069,856        NaN    245,960,093
# 3  South America   68,958,962       NaN   1,360,127        NaN     66,514,275
# 4        Oceania   14,620,573       NaN      30,157        NaN     14,485,385
#
#   NewRecovered ActiveCases Serious,Critical Population          Continent
# 0         +291   2,657,829            6,319        NaN      North America
# 1      +17,234  15,139,643           15,150        NaN               Asia
# 2         +956   1,806,061            5,467        NaN             Europe
# 3          NaN   1,084,560           10,078        NaN      South America
# 4          NaN     105,031               49        NaN  Australia/Oceania

# %%
df2.head()
# Out:
#    Country,Other   TotalCases NewCases TotalDeaths  NewDeaths TotalRecovered  \
# 0  North America  131,614,510   +1,673   1,692,258        8.0    127,145,461
# 1           Asia  221,467,169     +120   1,553,255        1.0    205,658,939
# 2         Europe  253,232,601      +26   2,100,643        NaN    248,565,603
# 3  South America   69,859,756      NaN   1,365,807        NaN     66,650,237
# 4        Oceania   14,844,285     +441      32,767        NaN     14,697,196
#
#   NewRecovered ActiveCases Serious,Critical Population          Continent
# 0      +10,829   2,776,791            6,699        NaN      North America
# 1         +398  14,254,975           14,733        NaN               Asia
# 2         +904   2,566,355            4,510        NaN             Europe
# 3          NaN   1,843,712            8,953        NaN      South America
# 4          NaN     114,322               40        NaN  Australia/Oceania

# %%
df3.head()
# Out:
#    Country,Other   TotalCases  NewCases TotalDeaths  NewDeaths TotalRecovered  \
# 0  North America  131,685,575       NaN   1,693,051        NaN    127,241,880
# 1           Asia  221,470,247       NaN   1,553,301        NaN    205,660,635
# 2         Europe  253,261,188       NaN   2,100,788        NaN    248,600,620
# 3  South America   69,859,756       NaN   1,365,807        NaN     66,650,237
# 4        Oceania   14,855,028     863.0      32,790        3.0     14,709,464
#
#   NewRecovered ActiveCases Serious,Critical Population          Continent
# 0         +651   2,750,644            6,580        NaN      North America
# 1         +265  14,256,311           14,733        NaN               Asia
# 2       +4,177   2,559,780            4,510        NaN             Europe
# 3          NaN   1,843,712            8,953        NaN      South America
# 4         +871     112,774               40        NaN  Australia/Oceania

# %%
df.tail(8)
# Out:
#         Country,Other TotalCases  NewCases TotalDeaths  NewDeaths  \
# 231        Montserrat      1,403       NaN           8        NaN
# 232              Niue        884       NaN         NaN        NaN
# 233  Diamond Princess        712       NaN          13        NaN
# 234           Tokelau         80       NaN         NaN        NaN
# 235      Vatican City         29       NaN         NaN        NaN
# 236    Western Sahara         10       NaN           1        NaN
# 237        MS Zaandam          9       NaN           2        NaN
# 238             China    503,302       NaN       5,272        NaN
#
#     TotalRecovered NewRecovered ActiveCases Serious,Critical     Population  \
# 231          1,376          NaN          19              NaN          4,965
# 232            874          NaN          10              NaN          1,622
# 233            699          NaN           0              NaN            NaN
# ...

# %%
df2.tail(8)
# Out:
#         Country,Other TotalCases NewCases TotalDeaths  NewDeaths  \
# 231        Montserrat      1,403      NaN           8        NaN
# 232              Niue      1,059      NaN         NaN        NaN
# 233  Diamond Princess        712      NaN          13        NaN
# 234           Tokelau         80      NaN         NaN        NaN
# 235      Vatican City         29      NaN         NaN        NaN
# 236    Western Sahara         10      NaN           1        NaN
# 237        MS Zaandam          9      NaN           2        NaN
# 238             China    503,302      NaN       5,272        NaN
#
#     TotalRecovered NewRecovered ActiveCases Serious,Critical     Population  \
# 231          1,376          NaN          19              NaN          4,965
# 232          1,056          NaN           3              NaN          1,622
# 233            699          NaN           0              NaN            NaN
# ...

# %%
df3.tail(8)
# Out:
#         Country,Other TotalCases  NewCases TotalDeaths  NewDeaths  \
# 231        Montserrat      1,403       NaN           8        NaN
# 232              Niue      1,059       NaN         NaN        NaN
# 233  Diamond Princess        712       NaN          13        NaN
# 234           Tokelau         80       NaN         NaN        NaN
# 235      Vatican City         29       NaN         NaN        NaN
# 236    Western Sahara         10       NaN           1        NaN
# 237        MS Zaandam          9       NaN           2        NaN
# 238             China    503,302       NaN       5,272        NaN
#
#     TotalRecovered NewRecovered ActiveCases Serious,Critical     Population  \
# 231          1,376          NaN          19              NaN          4,965
# 232          1,056          NaN           3              NaN          1,622
# 233            699          NaN           0              NaN            NaN
# ...

# %%
df
# Out:
#       Country,Other   TotalCases  NewCases TotalDeaths  NewDeaths  \
# 0     North America  127,806,060       NaN   1,643,501        NaN
# 1              Asia  220,571,348       2.0   1,549,069        NaN
# 2            Europe  249,836,010       NaN   2,069,856        NaN
# 3     South America   68,958,962       NaN   1,360,127        NaN
# 4           Oceania   14,620,573       NaN      30,157        NaN
# ..              ...          ...       ...         ...        ...
# 234         Tokelau           80       NaN         NaN        NaN
# 235    Vatican City           29       NaN         NaN        NaN
# 236  Western Sahara           10       NaN           1        NaN
# 237      MS Zaandam            9       NaN           2        NaN
# 238           China      503,302       NaN       5,272        NaN
#
#     TotalRecovered NewRecovered ActiveCases Serious,Critical     Population  \
# 0      123,504,730         +291   2,657,829            6,319            NaN
# ...

# %%
df2
# Out:
#       Country,Other   TotalCases NewCases TotalDeaths  NewDeaths  \
# 0     North America  131,614,510   +1,673   1,692,258        8.0
# 1              Asia  221,467,169     +120   1,553,255        1.0
# 2            Europe  253,232,601      +26   2,100,643        NaN
# 3     South America   69,859,756      NaN   1,365,807        NaN
# 4           Oceania   14,844,285     +441      32,767        NaN
# ..              ...          ...      ...         ...        ...
# 234         Tokelau           80      NaN         NaN        NaN
# 235    Vatican City           29      NaN         NaN        NaN
# 236  Western Sahara           10      NaN           1        NaN
# 237      MS Zaandam            9      NaN           2        NaN
# 238           China      503,302      NaN       5,272        NaN
#
#     TotalRecovered NewRecovered ActiveCases Serious,Critical     Population  \
# 0      127,145,461      +10,829   2,776,791            6,699            NaN
# ...

# %%
df3
# Out:
#       Country,Other   TotalCases  NewCases TotalDeaths  NewDeaths  \
# 0     North America  131,685,575       NaN   1,693,051        NaN
# 1              Asia  221,470,247       NaN   1,553,301        NaN
# 2            Europe  253,261,188       NaN   2,100,788        NaN
# 3     South America   69,859,756       NaN   1,365,807        NaN
# 4           Oceania   14,855,028     863.0      32,790        3.0
# ..              ...          ...       ...         ...        ...
# 234         Tokelau           80       NaN         NaN        NaN
# 235    Vatican City           29       NaN         NaN        NaN
# 236  Western Sahara           10       NaN           1        NaN
# 237      MS Zaandam            9       NaN           2        NaN
# 238           China      503,302       NaN       5,272        NaN
#
#     TotalRecovered NewRecovered ActiveCases Serious,Critical     Population  \
# 0      127,241,880         +651   2,750,644            6,580            NaN
# ...

# %%
df["TotalCases"]
# Out:
# 0      127,806,060
# 1      220,571,348
# 2      249,836,010
# 3       68,958,962
# 4       14,620,573
#           ...
# 234             80
# 235             29
# 236             10
# 237              9
# 238        503,302
# Name: TotalCases, Length: 239, dtype: object

# %%
df2["TotalCases"]
# Out:
# 0      131,614,510
# 1      221,467,169
# 2      253,232,601
# 3       69,859,756
# 4       14,844,285
#           ...
# 234             80
# 235             29
# 236             10
# 237              9
# 238        503,302
# Name: TotalCases, Length: 239, dtype: object

# %%
df3["TotalCases"]
# Out:
# 0      131,685,575
# 1      221,470,247
# 2      253,261,188
# 3       69,859,756
# 4       14,855,028
#           ...
# 234             80
# 235             29
# 236             10
# 237              9
# 238        503,302
# Name: TotalCases, Length: 239, dtype: object

# %%
df.head(60)
# Out:
#     Country,Other   TotalCases  NewCases TotalDeaths  NewDeaths  \
# 0   North America  127,806,060       NaN   1,643,501        NaN
# 1            Asia  220,571,348       2.0   1,549,069        NaN
# 2          Europe  249,836,010       NaN   2,069,856        NaN
# 3   South America   68,958,962       NaN   1,360,127        NaN
# 4         Oceania   14,620,573       NaN      30,157        NaN
# 5          Africa   12,836,851       NaN     258,825        NaN
# 6             NaN          721       NaN          15        NaN
# 7           World  694,630,525       2.0   6,911,550        0.0
# 8             USA  108,087,321       NaN   1,173,655        NaN
# 9           India   44,997,167       NaN     531,930        NaN
# 10         France   40,138,560       NaN     167,642        NaN
# 11        Germany   38,428,685       NaN     174,352        NaN
# 12         Brazil   37,771,706       NaN     705,313        NaN
# 13       S. Korea   34,436,586       NaN      35,812        NaN
# ...

# %%
df2.head(60)
# Out:
#     Country,Other   TotalCases NewCases TotalDeaths  NewDeaths TotalRecovered  \
# 0   North America  131,614,510   +1,673   1,692,258        8.0    127,145,461
# 1            Asia  221,467,169     +120   1,553,255        1.0    205,658,939
# 2          Europe  253,232,601      +26   2,100,643        NaN    248,565,603
# 3   South America   69,859,756      NaN   1,365,807        NaN     66,650,237
# 4         Oceania   14,844,285     +441      32,767        NaN     14,697,196
# 5          Africa   12,860,287      NaN     258,884        NaN     12,090,790
# 6             NaN          721      NaN          15        NaN            706
# 7           World  703,879,329   +2,260   7,003,629        9.0    674,808,932
# 8             USA  111,560,998   +1,673   1,216,375        8.0    109,318,965
# 9           India   45,030,332     +120     533,496        1.0            NaN
# 10         France   40,138,560      NaN     167,642        NaN     39,970,918
# ...

# %%
df3.head(60)
# Out:
#     Country,Other   TotalCases  NewCases TotalDeaths  NewDeaths  \
# 0   North America  131,685,575       NaN   1,693,051        NaN
# 1            Asia  221,470,247       NaN   1,553,301        NaN
# 2          Europe  253,261,188       NaN   2,100,788        NaN
# 3   South America   69,859,756       NaN   1,365,807        NaN
# 4         Oceania   14,855,028     863.0      32,790        3.0
# 5          Africa   12,860,287       NaN     258,884        NaN
# 6             NaN          721       NaN          15        NaN
# 7           World  703,992,802     863.0   7,004,636        3.0
# 8             USA  111,628,771       NaN   1,217,083        NaN
# 9           India   45,030,467       NaN     533,499        NaN
# 10         France   40,138,560       NaN     167,642        NaN
# 11        Germany   38,823,286       NaN     182,694        NaN
# 12         Brazil   38,452,504       NaN     709,963        NaN
# 13       S. Korea   34,571,873       NaN      35,934        NaN
# ...
